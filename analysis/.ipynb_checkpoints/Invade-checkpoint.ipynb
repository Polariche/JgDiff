# %%
import sys
import pandas as pd
import numpy as np
import path
import matplotlib.pyplot as plt
from sklearn.linear_model import Lasso, LinearRegression, Ridge
sys.path.insert(0, '..')
import bigdata

# %%
def trainSet(t):
    return t[t['matchId'].apply(lambda x: int(x)%5!=0)]

def testSet(t):
    return t[t['matchId'].apply(lambda x: int(x)%5==0)]

# %%
champions = pd.read_csv("../supplement/champions.csv")
champions = champions.reset_index().set_index('id')

# %%
matchroles = pd.read_csv("../supplement/matchrole.csv")
matchroles_tr = trainSet(matchroles).reset_index(drop=True)
matchroles_ts = testSet(matchroles).reset_index(drop=True)

# %%
kills = pd.read_csv("../supplement/kills.csv")
kills_tr = trainSet(kills).reset_index(drop=True)
kills_ts = testSet(kills).reset_index(drop=True)

# %%
firstkills = kills.groupby('matchId').first()

# %% [markdown]
# # Existence of Invasion

# %%
# kill around the first buff
invaded_tr = kills_tr.groupby('matchId').first()['timestamp'] < 105000
invaded_ts = kills_ts.groupby('matchId').first()['timestamp'] < 105000

# %%
df = pd.DataFrame(matchroles_tr.matchId).set_index('matchId')
df['invaded'] = invaded
df['invaded'] = df['invaded'].fillna(False)

# %%
matchroles.set_index('matchId').iloc[:,11:]
# Out:
#             Top_0_ch  Jgl_0_ch  Mid_0_ch  Bot_0_ch  Sup_0_ch  Top_1_ch  \
# matchId
# 3273218631       122        56        30        18        12       133
# 3273221800        80       163         4        81       201        79
# 3278904898        58        28         4       106        25        30
# 3287833940        27       141       266       202       555        36
# 3292739224        27       164       103        81        25       126
# 3292786341        24        60       103        74        25       266
# 3305077757        24        64       245        21       555        54
# 3305168152         8        59       105       110        16         6
# 3305223985       164       104        55        81        78        41
# 3305241992        58        79       142       145        54       122
# 3415011667       112        79       157       145       111        74
# 3415206653       112       164        13       236       111       122
# 3415334197        13        64       127       145       497        57
# 3415351108        14        60        84       236       412        68
# 3415420484        24       120        30       145       111        80
# 3415450255        58        79       266       145        43       127
# 3415743424        50        64        91       236        16         6
# 3415934716        68        64       238        15        16       516
# 3416150425        68        11        38       145       412        39
# 3416296019       114        76       127       119       267        24
# 3416371393        85       164         3       119       267       266
# 3417902499       112        64        91       236       497         2
# 3435462921       120         5       157        61       412        98
# 3435480254        14        76        53        67       412        39
# 3435513722        26       164        91       236        53       114
# 3435539108        68         5       157       145        25        36
# 3617771107         2        20       517        82        89        13
# 3633517433        92        64        34        81        79       517
# 3664646598        39       266        90       145         9        17
# 3688852009        24       421        55       236        40         8
# ...              ...       ...       ...       ...       ...       ...
# 3956334781        39        36        61       145        26        10
# 3956343540       107        64       127       145        40        98
# 3956346024        58        64       134        81        43       236
# 3956347889        84        60       238        50        26        10
# 3956351304       150       421       126       145       101        54
# 3956356832        83       163        13        22        26       114
# 3956364616        24        64       236        81         3        10
# 3956370579        82        64       157       236       111        98
# 3956373743       150        76         4        21        25        84
# 3956380430        24        64         7       498       412        54
# 3956381353       122       246        84        51        25        92
# 3956385003        80       120        13       145       106        10
# 3956386571       420        64        84       145        99        82
# 3956387184       126        79        58        22       412        78
# 3956392041        10        64         7       145       117        92
# 3956397151        41        56        38        22       412         8
# 3956403740        13       104        61       236       555       164
# 3956405482        84        28        18       222       412       266
# 3956416007       157        64        68       145       117       420
# 3956430832        84       154        67       145        79       238
# 3956441503       240        56       238       145       117        82
# 3956441753        68       245         3       110       412        75
# 3956445599       120       163       105        81        99        78
# 3956461246        39         2         8       222       412        38
# 3956471990       266        79       246       145       412       126
# 3956480499       126        11        44        67       117        31
# 3956483153       126        76       268        22        25        85
# 3956483610       240        30        84        18        89       114
# 3956484460         8       154         4        51       223        85
# 3956497316       120        64        74       498        26       114
#
#             Jgl_1_ch  Mid_1_ch  Bot_1_ch  Sup_1_ch
# matchId
# 3273218631       164        34         8         9
# 3273221800       107        55       202        25
# 3278904898       141        55       202        26
# 3287833940        35       126        61        53
# 3292739224       141         3       145        16
# 3292786341       164        34       202       267
# 3305077757        28        34       145        25
# 3305168152       113        90       202        43
# 3305223985        79        13       145       497
# 3305241992        64        38        22       432
# 3415011667       121        55       236        12
# 3415206653        64        84       145       432
# 3415334197       203         8        67       555
# 3415351108        80        69       145        79
# 3415420484       164       134        15        12
# 3415450255        64       105       236       555
# 3415743424       164        39       145       412
# 3415934716       203         4        81        40
# 3416150425        79        84       157       555
# 3416296019        64       245       236        79
# 3416371393        79        69       145       412
# 3417902499         5        69        15       432
# 3435462921       164       245        18       117
# 3435480254        60        38        50        30
# 3435513722        60        61        81        16
# 3435539108        64       126        15       412
# 3617771107         5        58       145        12
# 3633517433        59       266        82        89
# 3664646598        33        13        67        12
# 3688852009       120        13        81       555
# ...              ...       ...       ...       ...
# 3956334781       154       105       110        89
# 3956343540       203       105       498        53
# 3956346024       421         3       498        57
# 3956347889       107        68        81        89
# 3956351304        64        39       498       111
# 3956356832       517       266        21       267
# 3956364616        59       142        51        25
# 3956370579        79        58        22       412
# 3956373743        59       246        15        43
# 3956380430        76       246       119        89
# 3956381353       113       266        22        16
# 3956385003        79       127       498       555
# 3956386571        76       246        74        26
# 3956387184        76        80       145        89
# 3956392041       121        67       236        40
# 3956397151       163         4       145        89
# 3956403740       154         8        51        25
# 3956405482        64         8       145       111
# 3956416007       120       131       498        37
# 3956430832        59         8        15       497
# 3956441503        60        91       498       111
# 3956441753        64         7       236        53
# 3956445599       141         7       145        26
# 3956461246        60       127        81       432
# 3956471990        64       134        81        57
# 3956480499        64       136       145        40
# 3956483153        64       127       110        16
# 3956483610        64         8       145       412
# 3956484460        60        39       498       111
# 3956497316       421       134       236        53
#
# [18378 rows x 10 columns]

# %%
champions.loc[matchroles.set_index('matchId').iloc[:,11+0*5:11+0*5+5].loc[[3273221800,3305223985]].values.reshape(-1)]['index'].values
# Out:
# array([ 85, 112, 120,  26,  13,  15,  35,  52,  26,  86], dtype=int64)

# %%
def champ_onehot(match, team):
    a = np.zeros([len(match), len(champions)])
    for i in range(len(match)):
        a[i][champions.loc[matchroles.set_index('matchId').iloc[:,11+team*5:11+team*5+5].loc[match[i]].values.reshape(-1)]['index']] = 1
    return a

# %%
tr_matchids = matchroles_tr['matchId']
ts_matchids = matchroles_ts['matchId']

X_tr = np.concatenate([champ_onehot(tr_matchids, 0),champ_onehot(tr_matchids, 1)], axis=1)
X_ts = np.concatenate([champ_onehot(ts_matchids, 0),champ_onehot(ts_matchids, 1)], axis=1)

# %%
tr_matchids = matchroles_tr.index
ts_matchids = matchroles_ts.index

onehots_0 = champ_onehot(tr_matchids, 0)
onehots_1 = champ_onehot(tr_matchids, 0)

X = np.concatenate([onehots_0, onehots_1], axis=1)

# %%
X.shape
# Out:
# (14620, 290)

# %%
linear = LinearRegression().fit(X_tr, df['invaded'].astype(int))
np.mean(df['invaded'] == (linear.predict(X)  > 0.5))
# Out:
# 0.8104651162790698

# %%
ridge = Ridge().fit(X, df['invaded'].astype(int))
np.mean(df['invaded'] == (ridge.predict(X)  > 0.5))
# Out:
# 0.8105335157318742

# %%
lasso = Lasso().fit(X, df['invaded'].astype(int))
np.mean(df['invaded'] == (lasso.predict(X)  > 0.5))
# Out:
# 0.8105335157318742
