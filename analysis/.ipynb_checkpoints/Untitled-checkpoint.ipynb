# %%
import numpy as np
import pandas as pd
import path
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../supplement/matchrole.csv")
df =df[~(df==0).any(axis=1)]

# %%
champs = pd.read_csv("../supplement/champions.csv")
champs = champs.set_index('id')

# %%
tops = pd.concat([df["Top_0_championId"],df["Top_1_championId"]])
jgs = pd.concat([df["Jungle_0_championId"],df["Jungle_1_championId"]])
mids = pd.concat([df["Mid_0_championId"],df["Mid_1_championId"]])
bots = pd.concat([df["Bot_0_championId"],df["Bot_1_championId"]])
sups = pd.concat([df["Support_0_championId"],df["Support_1_championId"]])

# %% [markdown]
# # Basic Statistics

# %%
def count(line):
    return [(champs.loc[x[0]]['name'], x[1])for x in dict(line.value_counts()).items()]

def pickrate(line):
    return [(champs.loc[x[0]]['name'], x[1]/len(line)*200)for x in dict(line.value_counts()).items()]

# %%
pickrate(tops)
# Out:
# [('Kayle', 16.10151861868109),
#  ('Jayce', 11.254420636571666),
#  ('Vladimir', 10.047846889952153),
#  ('Jax', 9.236530060328688),
#  ('Akali', 9.007697108383606),
#  ('Renekton', 8.86207613896401),
#  ('Camille', 8.654046182650301),
#  ('Ryze', 8.40441023507385),
#  ('Irelia', 8.300395256916996),
#  ('Gangplank', 7.655502392344498),
#  ('Fiora', 7.405866444768047),
#  ('Kennen', 6.095277719991679),
#  ('Aatrox', 5.491990846681922),
#  ('Lucian', 5.117536925317245),
#  ('Pantheon', 4.431038069482005),
#  ('Mordekaiser', 3.6197212398585394),
#  ('Kled', 3.3700852922820888),
#  ('Poppy', 3.328479301019347),
#  ('Rengar', 3.2660703141252343),
#  ('Quinn', 3.1620553359683794),
#  ('Garen', 3.037237362180154),
#  ('Darius', 2.808404410235074),
#  ('Riven', 2.6835864364468485),
#  ('Rumble', 2.6211774495527354),
#  ('Ornn', 2.205117536925317),
#  ('Shen', 2.184314541293946),
#  ('Karma', 1.9346785937174955),
#  ('Tryndamere', 1.7058456417724153),
#  ('Yasuo', 1.5602246723528188),
#  ('Olaf', 1.518618681090077),
#  ('Heimerdinger', 1.497815685458706),
#  ('Sylas', 1.477012689827335),
#  ('Viktor', 1.3729977116704806),
#  ('Hecarim', 1.1441647597254003),
#  ('Vayne', 1.0609527771999168),
#  ('Gnar', 0.9777407946744331),
#  ('Talon', 0.9361348034116913),
#  ('Malphite', 0.9153318077803204),
#  ('Nocturne', 0.8737258165175785),
#  ('Tristana', 0.8529228208862076),
#  ('Sion', 0.8529228208862076),
#  ('Twisted Fate', 0.8113168296234657),
#  ('Singed', 0.8113168296234657),
#  ('Teemo', 0.769710838360724),
#  ('Zoe', 0.748907842729353),
#  ('Illaoi', 0.7281048470979821),
#  ('Qiyana', 0.7281048470979821),
#  ("Cho'Gath", 0.7073018514666112),
#  ('Urgot', 0.7073018514666112),
#  ('Volibear', 0.6656958602038693),
#  ('Maokai', 0.6448928645724984),
#  ('Gragas', 0.6448928645724984),
#  ('Ekko', 0.6240898689411275),
#  ('LeBlanc', 0.6032868733097566),
#  ('Kassadin', 0.5824838776783856),
#  ('Cassiopeia', 0.5824838776783856),
#  ('Galio', 0.5824838776783856),
#  ('Syndra', 0.5200748907842729),
#  ('Dr. Mundo', 0.499271895152902),
#  ('Malzahar', 0.499271895152902),
#  ('Wukong', 0.4576659038901602),
#  ('Xayah', 0.4576659038901602),
#  ('Neeko', 0.4576659038901602),
#  ('Zilean', 0.41605991262741837),
#  ('Fizz', 0.3952569169960474),
#  ("Kai'Sa", 0.3744539213646765),
#  ('Orianna', 0.3744539213646765),
#  ('Aurelion Sol', 0.3536509257333056),
#  ('Lulu', 0.2912419388391928),
#  ('Karthus', 0.2704389432078219),
#  ('Lee Sin', 0.2704389432078219),
#  ('Pyke', 0.249635947576451),
#  ('Lissandra', 0.249635947576451),
#  ('Zed', 0.249635947576451),
#  ('Draven', 0.249635947576451),
#  ('Swain', 0.2288329519450801),
#  ('Nidalee', 0.2288329519450801),
#  ('Ashe', 0.20802995631370919),
#  ('Anivia', 0.20802995631370919),
#  ('Yorick', 0.20802995631370919),
#  ('Ezreal', 0.20802995631370919),
#  ('Trundle', 0.18722696068233824),
#  ('Taliyah', 0.18722696068233824),
#  ('Katarina', 0.18722696068233824),
#  ('Ahri', 0.18722696068233824),
#  ('Jarvan IV', 0.18722696068233824),
#  ('Corki', 0.16642396505096732),
#  ('Warwick', 0.16642396505096732),
#  ('Veigar', 0.1456209694195964),
#  ('Rammus', 0.1456209694195964),
#  ('Nasus', 0.1456209694195964),
#  ('Master Yi', 0.1248179737882255),
#  ('Morgana', 0.1248179737882255),
#  ("Vel'Koz", 0.1248179737882255),
#  ('Miss Fortune', 0.10401497815685459),
#  ('Nautilus', 0.10401497815685459),
#  ('Graves', 0.10401497815685459),
#  ('Shyvana', 0.10401497815685459),
#  ('Leona', 0.10401497815685459),
#  ('Elise', 0.10401497815685459),
#  ("Rek'Sai", 0.08321198252548366),
#  ('Jinx', 0.08321198252548366),
#  ('Sivir', 0.08321198252548366),
#  ('Zac', 0.08321198252548366),
#  ('Diana', 0.08321198252548366),
#  ('Xerath', 0.06240898689411275),
#  ('Blitzcrank', 0.06240898689411275),
#  ('Azir', 0.06240898689411275),
#  ("Kha'Zix", 0.06240898689411275),
#  ('Alistar', 0.06240898689411275),
#  ('Annie', 0.06240898689411275),
#  ('Bard', 0.06240898689411275),
#  ('Tahm Kench', 0.04160599126274183),
#  ('Braum', 0.04160599126274183),
#  ('Ziggs', 0.04160599126274183),
#  ('Kayn', 0.04160599126274183),
#  ('Thresh', 0.04160599126274183),
#  ('Kindred', 0.04160599126274183),
#  ('Ivern', 0.04160599126274183),
#  ('Lux', 0.020802995631370915),
#  ('Caitlyn', 0.020802995631370915),
#  ('Evelynn', 0.020802995631370915),
#  ('Rakan', 0.020802995631370915),
#  ('Shaco', 0.020802995631370915),
#  ('Xin Zhao', 0.020802995631370915),
#  ('Twitch', 0.020802995631370915),
#  ('Fiddlesticks', 0.020802995631370915),
#  ('Janna', 0.020802995631370915),
#  ('Vi', 0.020802995631370915),
#  ('Soraka', 0.020802995631370915),
#  ('Taric', 0.020802995631370915)]

# %%
pickrate(jgs)
# Out:
# [('Lee Sin', 36.67568129810693),
#  ('Elise', 21.427085500312046),
#  ('Nidalee', 16.434366548783025),
#  ('Ekko', 14.832535885167463),
#  ("Rek'Sai", 13.293114208446017),
#  ('Gragas', 11.212814645308924),
#  ('Taliyah', 10.963178697732474),
#  ('Olaf', 10.921572706469732),
#  ('Karthus', 10.547118785105056),
#  ("Kha'Zix", 7.093821510297483),
#  ('Jarvan IV', 4.97191595589765),
#  ('Kindred', 4.847097982109424),
#  ('Xin Zhao', 4.264614104431038),
#  ('Graves', 2.808404410235074),
#  ('Kayn', 2.662783440815477),
#  ('Nunu & Willump', 2.4131474932390264),
#  ('Zac', 2.26752652381943),
#  ('Shyvana', 1.8514666111920117),
#  ('Qiyana', 1.6850426461410444),
#  ('Evelynn', 1.5602246723528188),
#  ('Ivern', 1.539421676721448),
#  ('Shaco', 1.518618681090077),
#  ('Vi', 1.2273767422508841),
#  ('Hecarim', 1.1233617640940294),
#  ('Nocturne', 0.9569377990430622),
#  ('Rengar', 0.9361348034116913),
#  ('Sylas', 0.8945288121489494),
#  ('Master Yi', 0.769710838360724),
#  ('Dr. Mundo', 0.7281048470979821),
#  ('Poppy', 0.7073018514666112),
#  ('Camille', 0.6240898689411275),
#  ('Warwick', 0.6240898689411275),
#  ('Fiddlesticks', 0.6032868733097566),
#  ('Jax', 0.4784688995215311),
#  ('Pantheon', 0.4576659038901602),
#  ('Sejuani', 0.41605991262741837),
#  ('Aatrox', 0.3952569169960474),
#  ('Amumu', 0.3952569169960474),
#  ('Rammus', 0.3536509257333056),
#  ('Twitch', 0.31204493447056375),
#  ('Skarner', 0.2704389432078219),
#  ('Taric', 0.1248179737882255),
#  ('Trundle', 0.1248179737882255),
#  ('Ezreal', 0.10401497815685459),
#  ('Kayle', 0.10401497815685459),
#  ('Rumble', 0.08321198252548366),
#  ('Fizz', 0.08321198252548366),
#  ('Urgot', 0.08321198252548366),
#  ('Fiora', 0.08321198252548366),
#  ('Kled', 0.06240898689411275),
#  ("Kai'Sa", 0.06240898689411275),
#  ('Renekton', 0.06240898689411275),
#  ('Jayce', 0.06240898689411275),
#  ('Riven', 0.06240898689411275),
#  ('Kennen', 0.06240898689411275),
#  ("Cho'Gath", 0.04160599126274183),
#  ('Garen', 0.04160599126274183),
#  ('Volibear', 0.04160599126274183),
#  ('Lucian', 0.04160599126274183),
#  ('Xayah', 0.04160599126274183),
#  ('Gangplank', 0.04160599126274183),
#  ('Gnar', 0.04160599126274183),
#  ('Jinx', 0.04160599126274183),
#  ('Tryndamere', 0.020802995631370915),
#  ('Wukong', 0.020802995631370915),
#  ('Tristana', 0.020802995631370915),
#  ('Twisted Fate', 0.020802995631370915),
#  ('Sion', 0.020802995631370915),
#  ('Kalista', 0.020802995631370915),
#  ('Yasuo', 0.020802995631370915),
#  ('Quinn', 0.020802995631370915),
#  ('Udyr', 0.020802995631370915),
#  ('Ryze', 0.020802995631370915),
#  ('Ornn', 0.020802995631370915),
#  ('Irelia', 0.020802995631370915),
#  ('Zilean', 0.020802995631370915),
#  ('Talon', 0.020802995631370915),
#  ('Karma', 0.020802995631370915),
#  ('Malphite', 0.020802995631370915),
#  ('Singed', 0.020802995631370915),
#  ('Shen', 0.020802995631370915),
#  ('Malzahar', 0.020802995631370915),
#  ('Mordekaiser', 0.020802995631370915),
#  ('Vladimir', 0.020802995631370915)]

# %%
pickrate(mids)
# Out:
# [('Akali', 12.044934470563762),
#  ('Qiyana', 11.628874557936344),
#  ('Twisted Fate', 10.276679841897234),
#  ('Zoe', 9.777407946744331),
#  ('Ryze', 8.38360723944248),
#  ('Talon', 7.863532348658207),
#  ('LeBlanc', 7.6971083836072385),
#  ('Yasuo', 5.949656750572083),
#  ('Irelia', 5.42958185978781),
#  ('Pantheon', 5.304763885999584),
#  ('Galio', 5.159142916579987),
#  ('Kayle', 5.0967339296858745),
#  ('Lucian', 4.97191595589765),
#  ('Jayce', 4.867900977740795),
#  ('Syndra', 3.9525691699604746),
#  ('Fizz', 3.827751196172249),
#  ('Orianna', 3.786145204909507),
#  ('Zed', 3.6197212398585394),
#  ('Renekton', 3.5989182442271686),
#  ('Camille', 3.557312252964427),
#  ('Vladimir', 3.349282296650718),
#  ('Katarina', 3.016434366548783),
#  ('Taliyah', 2.933222384023299),
#  ('Aurelion Sol', 2.8708133971291865),
#  ('Nocturne', 2.8292074058664447),
#  ('Aatrox', 2.6419804451841067),
#  ('Ahri', 2.371541501976284),
#  ('Ezreal', 2.3299355107135424),
#  ('Kassadin', 2.2883295194508007),
#  ('Lissandra', 2.2259205325566884),
#  ('Ekko', 2.1219055543998335),
#  ('Tristana', 2.059496567505721),
#  ('Viktor', 1.9554815893488662),
#  ('Cassiopeia', 1.8722696068233826),
#  ('Sylas', 1.7890576242978988),
#  ('Rumble', 1.7266486374037862),
#  ('Malzahar', 1.6018306636155606),
#  ('Heimerdinger', 1.518618681090077),
#  ('Garen', 1.3938007073018515),
#  ('Karma', 1.3521947160391097),
#  ('Anivia', 1.1441647597254003),
#  ("Kai'Sa", 1.1233617640940294),
#  ('Kled', 1.0817557728312877),
#  ('Pyke', 1.0609527771999168),
#  ("Vel'Koz", 1.0401497815685459),
#  ('Zilean', 0.9153318077803204),
#  ('Gangplank', 0.9153318077803204),
#  ('Annie', 0.9153318077803204),
#  ('Jax', 0.8945288121489494),
#  ('Diana', 0.8321198252548367),
#  ('Veigar', 0.8113168296234657),
#  ('Quinn', 0.7905138339920948),
#  ('Azir', 0.769710838360724),
#  ('Mordekaiser', 0.748907842729353),
#  ('Poppy', 0.7281048470979821),
#  ('Nautilus', 0.6656958602038693),
#  ('Fiora', 0.6448928645724984),
#  ('Xayah', 0.6448928645724984),
#  ('Tryndamere', 0.6240898689411275),
#  ('Kennen', 0.5616808820470147),
#  ('Lulu', 0.5408778864156438),
#  ('Neeko', 0.499271895152902),
#  ('Malphite', 0.4784688995215311),
#  ('Thresh', 0.4576659038901602),
#  ('Ashe', 0.41605991262741837),
#  ('Leona', 0.41605991262741837),
#  ('Vayne', 0.3952569169960474),
#  ('Karthus', 0.3952569169960474),
#  ('Corki', 0.3744539213646765),
#  ('Blitzcrank', 0.3744539213646765),
#  ('Ornn', 0.33284793010193464),
#  ('Rakan', 0.31204493447056375),
#  ('Xerath', 0.2912419388391928),
#  ('Maokai', 0.2704389432078219),
#  ('Sion', 0.249635947576451),
#  ('Swain', 0.249635947576451),
#  ('Riven', 0.249635947576451),
#  ('Darius', 0.249635947576451),
#  ("Cho'Gath", 0.2288329519450801),
#  ('Gragas', 0.2288329519450801),
#  ('Draven', 0.2288329519450801),
#  ('Shen', 0.2288329519450801),
#  ('Miss Fortune', 0.2288329519450801),
#  ('Morgana', 0.18722696068233824),
#  ('Tahm Kench', 0.18722696068233824),
#  ('Master Yi', 0.18722696068233824),
#  ('Singed', 0.18722696068233824),
#  ('Ziggs', 0.18722696068233824),
#  ('Lux', 0.16642396505096732),
#  ('Taric', 0.16642396505096732),
#  ('Teemo', 0.16642396505096732),
#  ('Braum', 0.16642396505096732),
#  ('Hecarim', 0.16642396505096732),
#  ('Nunu & Willump', 0.1456209694195964),
#  ('Olaf', 0.1456209694195964),
#  ('Jinx', 0.1456209694195964),
#  ('Zac', 0.1456209694195964),
#  ('Volibear', 0.1456209694195964),
#  ('Gnar', 0.1248179737882255),
#  ('Fiddlesticks', 0.1248179737882255),
#  ('Alistar', 0.10401497815685459),
#  ('Rengar', 0.10401497815685459),
#  ('Yuumi', 0.10401497815685459),
#  ('Varus', 0.08321198252548366),
#  ('Janna', 0.08321198252548366),
#  ('Sivir', 0.08321198252548366),
#  ('Urgot', 0.08321198252548366),
#  ('Dr. Mundo', 0.06240898689411275),
#  ('Kalista', 0.06240898689411275),
#  ('Graves', 0.06240898689411275),
#  ('Bard', 0.06240898689411275),
#  ('Soraka', 0.06240898689411275),
#  ('Jhin', 0.06240898689411275),
#  ('Wukong', 0.06240898689411275),
#  ('Shyvana', 0.06240898689411275),
#  ('Jarvan IV', 0.06240898689411275),
#  ('Zyra', 0.04160599126274183),
#  ('Vi', 0.04160599126274183),
#  ('Yorick', 0.04160599126274183),
#  ('Nasus', 0.04160599126274183),
#  ('Caitlyn', 0.04160599126274183),
#  ('Twitch', 0.04160599126274183),
#  ('Warwick', 0.04160599126274183),
#  ('Ivern', 0.020802995631370915),
#  ('Kindred', 0.020802995631370915),
#  ('Nidalee', 0.020802995631370915),
#  ('Illaoi', 0.020802995631370915),
#  ("Kha'Zix", 0.020802995631370915)]

# %%
pickrate(bots)
# Out:
# [("Kai'Sa", 48.45017682546286),
#  ('Xayah', 25.85812356979405),
#  ('Ezreal', 24.006656958602036),
#  ('Ashe', 19.638027876014146),
#  ('Lucian', 16.455169544414396),
#  ('Miss Fortune', 12.294570418140212),
#  ('Jinx', 8.737258165175785),
#  ('Caitlyn', 7.093821510297483),
#  ('Vayne', 3.557312252964427),
#  ('Draven', 3.4116912835448305),
#  ('Yasuo', 3.1620553359683794),
#  ('Heimerdinger', 2.8292074058664447),
#  ('Varus', 2.4339504888703973),
#  ('Tristana', 1.997087580611608),
#  ('Sivir', 1.6434366548783026),
#  ('Jhin', 1.5810276679841897),
#  ('Kalista', 1.4562096941959641),
#  ('Syndra', 1.2897857291449968),
#  ('Twitch', 1.1025587684626585),
#  ("Kog'Maw", 0.7281048470979821),
#  ('Taliyah', 0.6656958602038693),
#  ('Swain', 0.5824838776783856),
#  ('Viktor', 0.4784688995215311),
#  ('Kayle', 0.4784688995215311),
#  ('Irelia', 0.43686290825878926),
#  ('Vladimir', 0.3952569169960474),
#  ('Kindred', 0.3536509257333056),
#  ('Garen', 0.33284793010193464),
#  ('Ryze', 0.33284793010193464),
#  ('Akali', 0.31204493447056375),
#  ('Pantheon', 0.31204493447056375),
#  ('Zoe', 0.2912419388391928),
#  ('Galio', 0.249635947576451),
#  ('Twisted Fate', 0.249635947576451),
#  ('Neeko', 0.249635947576451),
#  ('Talon', 0.2288329519450801),
#  ('Renekton', 0.2288329519450801),
#  ('Olaf', 0.20802995631370919),
#  ('Orianna', 0.20802995631370919),
#  ('Lee Sin', 0.20802995631370919),
#  ('Veigar', 0.20802995631370919),
#  ('Karma', 0.18722696068233824),
#  ('Camille', 0.18722696068233824),
#  ('Qiyana', 0.16642396505096732),
#  ('Poppy', 0.16642396505096732),
#  ('Thresh', 0.16642396505096732),
#  ('LeBlanc', 0.16642396505096732),
#  ('Nautilus', 0.16642396505096732),
#  ('Tahm Kench', 0.1456209694195964),
#  ('Rengar', 0.1456209694195964),
#  ('Jayce', 0.1248179737882255),
#  ('Karthus', 0.1248179737882255),
#  ('Jax', 0.1248179737882255),
#  ("Vel'Koz", 0.10401497815685459),
#  ('Kennen', 0.10401497815685459),
#  ('Aatrox', 0.10401497815685459),
#  ('Rakan', 0.10401497815685459),
#  ('Rumble', 0.10401497815685459),
#  ('Zilean', 0.10401497815685459),
#  ('Leona', 0.10401497815685459),
#  ('Fizz', 0.10401497815685459),
#  ('Mordekaiser', 0.08321198252548366),
#  ('Volibear', 0.08321198252548366),
#  ('Fiora', 0.08321198252548366),
#  ('Gangplank', 0.08321198252548366),
#  ('Tryndamere', 0.08321198252548366),
#  ('Shen', 0.08321198252548366),
#  ('Zed', 0.08321198252548366),
#  ('Pyke', 0.08321198252548366),
#  ('Blitzcrank', 0.08321198252548366),
#  ('Nidalee', 0.08321198252548366),
#  ('Elise', 0.08321198252548366),
#  ('Ekko', 0.08321198252548366),
#  ('Quinn', 0.08321198252548366),
#  ('Ornn', 0.06240898689411275),
#  ('Anivia', 0.06240898689411275),
#  ("Rek'Sai", 0.06240898689411275),
#  ('Malzahar', 0.06240898689411275),
#  ('Katarina', 0.06240898689411275),
#  ('Darius', 0.06240898689411275),
#  ('Morgana', 0.06240898689411275),
#  ('Gragas', 0.06240898689411275),
#  ('Xin Zhao', 0.06240898689411275),
#  ('Sylas', 0.04160599126274183),
#  ('Teemo', 0.04160599126274183),
#  ('Fiddlesticks', 0.04160599126274183),
#  ('Kled', 0.04160599126274183),
#  ("Cho'Gath", 0.04160599126274183),
#  ('Ahri', 0.04160599126274183),
#  ('Jarvan IV', 0.04160599126274183),
#  ('Yuumi', 0.04160599126274183),
#  ('Lissandra', 0.04160599126274183),
#  ('Singed', 0.04160599126274183),
#  ('Azir', 0.020802995631370915),
#  ('Bard', 0.020802995631370915),
#  ('Soraka', 0.020802995631370915),
#  ('Cassiopeia', 0.020802995631370915),
#  ('Nocturne', 0.020802995631370915),
#  ('Nasus', 0.020802995631370915),
#  ('Sona', 0.020802995631370915),
#  ('Shaco', 0.020802995631370915),
#  ('Graves', 0.020802995631370915),
#  ('Aurelion Sol', 0.020802995631370915),
#  ('Master Yi', 0.020802995631370915),
#  ('Lux', 0.020802995631370915),
#  ('Annie', 0.020802995631370915),
#  ('Illaoi', 0.020802995631370915),
#  ('Xerath', 0.020802995631370915),
#  ('Ziggs', 0.020802995631370915),
#  ('Rammus', 0.020802995631370915),
#  ('Sion', 0.020802995631370915),
#  ('Dr. Mundo', 0.020802995631370915),
#  ("Kha'Zix", 0.020802995631370915),
#  ('Urgot', 0.020802995631370915),
#  ('Riven', 0.020802995631370915),
#  ('Wukong', 0.020802995631370915),
#  ('Lulu', 0.020802995631370915)]

# %%
pickrate(sups)
# Out:
# [('Thresh', 27.023091325150823),
#  ('Nautilus', 22.6752652381943),
#  ('Leona', 17.22488038277512),
#  ('Rakan', 14.520490950696901),
#  ('Blitzcrank', 12.336176409402954),
#  ('Morgana', 9.73580195548159),
#  ('Pyke', 9.652589972956106),
#  ('Tahm Kench', 9.132515082171832),
#  ('Janna', 6.781776575826918),
#  ('Bard', 6.220095693779904),
#  ('Karma', 5.533596837944664),
#  ('Alistar', 4.680674017058457),
#  ('Soraka', 4.243811108799667),
#  ('Fiddlesticks', 4.1605991262741835),
#  ('Gragas', 3.973372165591845),
#  ('Lulu', 3.536509257333056),
#  ('Braum', 3.1204493447056376),
#  ('Galio', 3.016434366548783),
#  ('Volibear', 2.662783440815477),
#  ('Yuumi', 2.309132515082172),
#  ('Lux', 2.2883295194508007),
#  ('Shen', 1.7890576242978988),
#  ('Ornn', 1.747451633035157),
#  ('Swain', 1.7266486374037862),
#  ('Nami', 1.5810276679841897),
#  ('Zilean', 1.518618681090077),
#  ('Maokai', 1.3729977116704806),
#  ('Zyra', 1.248179737882255),
#  ("Vel'Koz", 1.185770750988142),
#  ('Shaco', 0.8113168296234657),
#  ('Taric', 0.6864988558352403),
#  ('Sona', 0.6656958602038693),
#  ('Poppy', 0.5824838776783856),
#  ('Zac', 0.5408778864156438),
#  ('Neeko', 0.5408778864156438),
#  ('Xerath', 0.4784688995215311),
#  ('Brand', 0.3952569169960474),
#  ('Akali', 0.3744539213646765),
#  ('Kayle', 0.31204493447056375),
#  ('Lucian', 0.31204493447056375),
#  ('Jarvan IV', 0.31204493447056375),
#  ("Kai'Sa", 0.2704389432078219),
#  ('Veigar', 0.2704389432078219),
#  ('Renekton', 0.249635947576451),
#  ('LeBlanc', 0.2288329519450801),
#  ('Zoe', 0.2288329519450801),
#  ('Ezreal', 0.2288329519450801),
#  ('Vladimir', 0.2288329519450801),
#  ('Xayah', 0.20802995631370919),
#  ('Ryze', 0.20802995631370919),
#  ('Pantheon', 0.20802995631370919),
#  ('Jayce', 0.18722696068233824),
#  ('Taliyah', 0.16642396505096732),
#  ('Twisted Fate', 0.16642396505096732),
#  ('Camille', 0.1456209694195964),
#  ('Olaf', 0.1456209694195964),
#  ('Sylas', 0.1456209694195964),
#  ('Lee Sin', 0.1456209694195964),
#  ('Kennen', 0.1456209694195964),
#  ('Syndra', 0.1248179737882255),
#  ('Aurelion Sol', 0.1248179737882255),
#  ('Heimerdinger', 0.1248179737882255),
#  ('Elise', 0.1248179737882255),
#  ('Sion', 0.1248179737882255),
#  ('Talon', 0.1248179737882255),
#  ('Qiyana', 0.1248179737882255),
#  ('Ekko', 0.10401497815685459),
#  ('Miss Fortune', 0.10401497815685459),
#  ('Viktor', 0.10401497815685459),
#  ('Karthus', 0.10401497815685459),
#  ('Fiora', 0.10401497815685459),
#  ('Rumble', 0.08321198252548366),
#  ("Rek'Sai", 0.08321198252548366),
#  ('Mordekaiser', 0.08321198252548366),
#  ('Fizz', 0.08321198252548366),
#  ('Yasuo', 0.08321198252548366),
#  ('Gangplank', 0.08321198252548366),
#  ('Trundle', 0.06240898689411275),
#  ('Irelia', 0.06240898689411275),
#  ('Nocturne', 0.06240898689411275),
#  ('Lissandra', 0.06240898689411275),
#  ('Teemo', 0.06240898689411275),
#  ('Katarina', 0.06240898689411275),
#  ('Aatrox', 0.06240898689411275),
#  ('Tristana', 0.06240898689411275),
#  ('Quinn', 0.06240898689411275),
#  ('Xin Zhao', 0.06240898689411275),
#  ('Anivia', 0.06240898689411275),
#  ('Garen', 0.06240898689411275),
#  ('Singed', 0.06240898689411275),
#  ('Master Yi', 0.04160599126274183),
#  ('Orianna', 0.04160599126274183),
#  ('Kled', 0.04160599126274183),
#  ('Annie', 0.04160599126274183),
#  ('Nidalee', 0.04160599126274183),
#  ('Darius', 0.04160599126274183),
#  ('Sejuani', 0.04160599126274183),
#  ('Sivir', 0.04160599126274183),
#  ('Tryndamere', 0.04160599126274183),
#  ('Malzahar', 0.04160599126274183),
#  ('Zed', 0.020802995631370915),
#  ('Graves', 0.020802995631370915),
#  ('Urgot', 0.020802995631370915),
#  ('Draven', 0.020802995631370915),
#  ('Malphite', 0.020802995631370915),
#  ('Twitch', 0.020802995631370915),
#  ('Wukong', 0.020802995631370915),
#  ('Corki', 0.020802995631370915),
#  ('Vayne', 0.020802995631370915),
#  ('Ahri', 0.020802995631370915),
#  ("Kha'Zix", 0.020802995631370915),
#  ('Azir', 0.020802995631370915),
#  ('Rammus', 0.020802995631370915),
#  ('Ashe', 0.020802995631370915)]

# %% [markdown]
# # Mapping Death

# %%
def setMap(gca):
    gca.set_xlim([0,15000])
    gca.set_ylim([0,15000])
    img = plt.imread("../statics/minimap.png")
    gca.imshow(img,extent=[-200, 15000, -200, 15000], interpolation='nearest')
    gca.set_aspect('equal')

# %%
# %matplotlib inline

def mapDeath(championId, col0, col1):
    plt.figure(figsize=(16, 16))
    setMap(plt.gca())

    kayleGames = [df[df[col0+"_championId"] == championId], df[df[col1+"_championId"] == championId]]
    for i in range(2):
        column = col0+"_id" if i==0 else col1+"_id"
        color = 'b' if i==0 else 'r'
        for j in range(len(kayleGames[i])):
            m = kayleGames[i].iloc[j]
            try:
                kills = pd.read_csv(f"../supplement/kills/{m.matchId}.csv")
            except FileNotFoundError: continue

            deaths = kills[kills.death==m[column]][kills.timestamp < 60*1000*10]
            plt.scatter(deaths['x'], deaths['y'], color=color)

# %%
mapDeath(10, "Top_0", "Top_1") # kayle
# Out:
# C:\Users\Polar\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
mapDeath(8, "Top_0", "Top_1") # vladimir
# Out:
# C:\Users\Polar\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
mapDeath(39, "Top_0", "Top_1")  # irelia
# Out:
# C:\Users\Polar\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
mapDeath(58, "Top_0", "Top_1")  # Renekton
# Out:
# C:\Users\Polar\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
